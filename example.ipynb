# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: MacOSX

# %%
# this is a comment
dat = pd.DataFrame.from_csv('/Users/birdy/Documents/workspace/VEGAS/DecisionMakingResultsLCOE.txt', index_col=None, sep=' ')
# Out:
# /Users/birdy/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
dat.head(15)
# Out:
#     reactor_build_decision  htgr_capital_cost  sfr_capital_cost    g_lcoe  \
# 0                        0                  0                 0  0.415166
# 1                        0                  0                 1  0.415166
# 2                        0                  0                 2  0.415166
# 3                        0                  1                 0  0.415166
# 4                        0                  1                 1  0.415166
# 5                        0                  1                 2  0.415166
# 6                        0                  2                 0  0.415166
# 7                        0                  2                 1  0.415166
# 8                        0                  2                 2  0.415166
# 9                        1                  0                 0  0.394595
# 10                       1                  0                 0  0.314190
# 11                       1                  0                 1  0.394595
# 12                       1                  0                 1  0.314190
# 13                       1                  0                 2  0.394595
# 14                       1                  0                 2  0.314190
#
#       u_lcoe
# 0   9.716755
# 1   9.716755
# 2   9.716755
# 3   9.716755
# 4   9.716755
# 5   9.716755
# 6   9.716755
# 7   9.716755
# 8   9.716755
# 9   9.634036
# 10  9.300388
# 11  9.634036
# 12  9.300388
# 13  9.634036
# 14  9.300388

# %%
dat['lcoe'] = dat['g_lcoe'] + dat['u_lcoe']

# %%
dat.head(15)
# Out:
#     reactor_build_decision  htgr_capital_cost  sfr_capital_cost    g_lcoe  \
# 0                        0                  0                 0  0.415166
# 1                        0                  0                 1  0.415166
# 2                        0                  0                 2  0.415166
# 3                        0                  1                 0  0.415166
# 4                        0                  1                 1  0.415166
# 5                        0                  1                 2  0.415166
# 6                        0                  2                 0  0.415166
# 7                        0                  2                 1  0.415166
# 8                        0                  2                 2  0.415166
# 9                        1                  0                 0  0.394595
# 10                       1                  0                 0  0.314190
# 11                       1                  0                 1  0.394595
# 12                       1                  0                 1  0.314190
# 13                       1                  0                 2  0.394595
# 14                       1                  0                 2  0.314190
#
#       u_lcoe       lcoe
# 0   9.716755  10.131921
# 1   9.716755  10.131921
# 2   9.716755  10.131921
# 3   9.716755  10.131921
# 4   9.716755  10.131921
# 5   9.716755  10.131921
# 6   9.716755  10.131921
# 7   9.716755  10.131921
# 8   9.716755  10.131921
# 9   9.634036  10.028631
# 10  9.300388   9.614578
# 11  9.634036  10.028631
# 12  9.300388   9.614578
# 13  9.634036  10.028631
# 14  9.300388   9.614578

# %%
for i in range(len(dat)):
    dat["marker"] = "0"

# %%
#np.where(dat['reactor_build_decision'] == 0, dat['marker'] = '.')
#np.where(dat['reactor_build_decision'] == 1, dat['marker'] = 'o')

def f(x):
    # takes a row and then returns the desired string for a marker type
    if x['reactor_build_decision'] == 0:
        return '.'
    elif x['reactor_build_decision'] == 1:
        return '+'
    elif x['reactor_build_decision'] == 2:
        return 'o'
    else:
        # last possibility is RBD is 3
        return '*'
    
dat['marker'] = dat.apply(f, axis=1)

# %%
dat.tail(10)
# Out:
#      reactor_build_decision  htgr_capital_cost  sfr_capital_cost    g_lcoe  \
# 431                       3                  2                 0  0.299672
# 432                       3                  2                 0  0.240359
# 433                       3                  2                 1  0.326800
# 434                       3                  2                 1  0.244934
# 435                       3                  2                 1  0.299672
# 436                       3                  2                 1  0.240359
# 437                       3                  2                 2  0.326800
# 438                       3                  2                 2  0.244934
# 439                       3                  2                 2  0.299672
# 440                       3                  2                 2  0.240359
#
#        u_lcoe       lcoe marker
# 431  9.691048   9.990719      *
# 432  9.705889   9.946249      *
# 433  9.760074  10.086874      *
# 434  9.721755   9.966689      *
# 435  9.714279  10.013951      *
# 436  9.732901   9.973260      *
# 437  9.773350  10.100150      *
# 438  9.734993   9.979928      *
# 439  9.737483  10.037155      *
# 440  9.759885  10.000245      *

# %%
dat_build_one
for i in range(dat.shape[0]):

# %%
dat.loc[6][2]
# Out:
# 0

# %%
len(dat)
#dat.loc[440][0]
# Out:
# 441

# %%
for i in range(dat.shape[0]):
    if (dat.loc[i]['reactor_build_decision'] == "0"): 
        dat.loc[i]['marker'] = "."
        #value = 1
    elif (dat.loc[i]['reactor_build_decision'] == "1"):
        dat.loc[i]['marker'] = "+"
    elif (dat.loc[i]['reactor_build_decision'] == "2"):
        dat.loc[i]['marker'] = "o"
    elif (dat.loc[i]['reactor_build_decision'] == "3"):
        dat.loc[i]['marker'] == "*"
#value

# %%
#for i in range(dat.shape[0]):
#    if (dat.loc[i][0] == "0"): 
#        dat.loc[i][6] = "."
#        #value = 1
#    elif (dat.loc[i][0] == "1"):
#        dat.loc[i][6] = "+"
#    elif (dat.loc[i][0] == "2"):
#        dat.loc[i][6] = "o"
#    elif (dat.loc[i][0] == "3"):
#        dat.loc[i][6] == "*"
#value

# %%
dat.head(15)
# Out:
#     reactor_build_decision  htgr_capital_cost  sfr_capital_cost    g_lcoe  \
# 0                        0                  0                 0  0.415166
# 1                        0                  0                 1  0.415166
# 2                        0                  0                 2  0.415166
# 3                        0                  1                 0  0.415166
# 4                        0                  1                 1  0.415166
# 5                        0                  1                 2  0.415166
# 6                        0                  2                 0  0.415166
# 7                        0                  2                 1  0.415166
# 8                        0                  2                 2  0.415166
# 9                        1                  0                 0  0.394595
# 10                       1                  0                 0  0.314190
# 11                       1                  0                 1  0.394595
# 12                       1                  0                 1  0.314190
# 13                       1                  0                 2  0.394595
# 14                       1                  0                 2  0.314190
#
#       u_lcoe       lcoe marker
# 0   9.716755  10.131921      .
# 1   9.716755  10.131921      .
# 2   9.716755  10.131921      .
# 3   9.716755  10.131921      .
# 4   9.716755  10.131921      .
# 5   9.716755  10.131921      .
# 6   9.716755  10.131921      .
# 7   9.716755  10.131921      .
# 8   9.716755  10.131921      .
# 9   9.634036  10.028631      +
# 10  9.300388   9.614578      +
# 11  9.634036  10.028631      +
# 12  9.300388   9.614578      +
# 13  9.634036  10.028631      +
# 14  9.300388   9.614578      +

# %%
dat.groupby(['reactor_build_decision','htgr_capital_cost'])

# %%
print dat.groupby(['reactor_build_decision','htgr_capital_cost']).mean().to_latex()
# Out:
# \begin{tabular}{llrrr}
# \toprule
#   &   &  sfr\_capital\_cost &    g\_lcoe &    u\_lcoe \\
# reactor\_build\_decision & htgr\_capital\_cost &                   &           &           \\
# \midrule
# 0 & 0 &                 1 &  0.415166 &  9.716755 \\
#   & 1 &                 1 &  0.415166 &  9.716755 \\
#   & 2 &                 1 &  0.415166 &  9.716755 \\
# 1 & 0 &                 1 &  0.301610 &  9.313882 \\
#   & 1 &                 1 &  0.301610 &  9.503287 \\
#   & 2 &                 1 &  0.301610 &  9.692639 \\
# 2 & 0 &                 1 &  0.385699 &  9.716187 \\
#   & 1 &                 1 &  0.385699 &  9.716187 \\
#   & 2 &                 1 &  0.385699 &  9.716187 \\
# 3 & 0 &                 1 &  0.304503 &  9.382353 \\
#   & 1 &                 1 &  0.304503 &  9.538982 \\
#   & 2 &                 1 &  0.304503 &  9.695560 \\
# \bottomrule
# \end{tabular}

# %%
# set styles
sns.set(style="whitegrid", palette="dark", color_codes=True, context='talk')

# Draw a nested violinplot and split the violins for easier comparison
g = sns.lmplot(x="g_lcoe", y="u_lcoe", hue="reactor_build_decision",
               truncate=True, size=5, data=dat, fit_reg=False, scatter_kws={"s": 25})

sns.despine(left=True)

plt.show()

# %%
sns.set(style="whitegrid", palette="dark", color_codes=True, context='talk')

#z = np.random.rand(3, 100)
#cmap = sns.cubehelix_palette(as_cmap=True)

# %%
for i in range(len(dat)):
    build_decision_one = dat[dat['reactor_build_decision'] == 0]
    build_decision_two = dat[dat['reactor_build_decision'] == 1]
    build_decision_three = dat[dat['reactor_build_decision'] == 2]
    build_decision_four = dat[dat['reactor_build_decision'] == 3]

# %%
build_decision_two.head(10)
# Out:
#     reactor_build_decision  htgr_capital_cost  sfr_capital_cost    g_lcoe  \
# 9                        1                  0                 0  0.394595
# 10                       1                  0                 0  0.314190
# 11                       1                  0                 1  0.394595
# 12                       1                  0                 1  0.314190
# 13                       1                  0                 2  0.394595
# 14                       1                  0                 2  0.314190
# 15                       1                  1                 0  0.394595
# 16                       1                  1                 0  0.314190
# 17                       1                  1                 1  0.394595
# 18                       1                  1                 1  0.314190
#
#       u_lcoe       lcoe marker
# 9   9.634036  10.028631      +
# 10  9.300388   9.614578      +
# 11  9.634036  10.028631      +
# 12  9.300388   9.614578      +
# 13  9.634036  10.028631      +
# 14  9.300388   9.614578      +
# 15  9.670655  10.065249      +
# 16  9.485312   9.799502      +
# 17  9.670655  10.065249      +
# 18  9.485312   9.799502      +

# %%
sns.set(font_scale=.75)

#sns.factorplot(x="g_lcoe", y="u_lcoe", hue="reactor_build_decision",
              #data=dat, kind="box", size=4, aspect=.5, marker=dat['marker']);
    
#sns.jointplot(x="g_lcoe", y="u_lcoe", hue="reactor_build_decision",
              #data=dat, size=6, aspect=.5);
    
#sns.jointplot(x="g_lcoe", y="u_lcoe",
              #data=dat, kind="scatter", hue="marker");
    

sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_one, fit_reg=False, marker="s", label="LWRs")
sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_two, fit_reg=False, marker="3", label="HTGR", scatter_kws={"s": 100*"lcoe"})
sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_three, fit_reg=False, marker="v", label="SFR")
sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_four, fit_reg=False, marker="*", label="SFR and HTGR")

plt.legend()

plt.show()
    
#plt.scatter(dat["g_lcoe"], dat["u_lcoe"], MarkerStyle=dat["marker"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-201-12565dc8a450> in <module>()
#      12
#      13 sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_one, fit_reg=False, marker="s", label="LWRs")
# ---> 14 sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_two, fit_reg=False, marker="3", label="HTGR", scatter_kws={"s": 100*"lcoe"})
#      15 sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_three, fit_reg=False, marker="v", label="SFR")
#      16 sns.regplot(x="g_lcoe", y="u_lcoe", data=build_decision_four, fit_reg=False, marker="*", label="SFR and HTGR")
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/seaborn/regression.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     788     scatter_kws["marker"] = marker
#     789     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 790     plotter.plot(ax, scatter_kws, line_kws)
#     791     return ax
#     792
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/seaborn/regression.pyc in plot(self, ax, scatter_kws, line_kws)
#     338         # Draw the constituent plots
#     339         if self.scatter:
# --> 340             self.scatterplot(ax, scatter_kws)
#     341         if self.fit_reg:
#     342             self.lineplot(ax, line_kws)
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/seaborn/regression.pyc in scatterplot(self, ax, kws)
#     367
#     368             x, y = self.scatter_data
# --> 369             ax.scatter(x, y, **kws)
#     370         else:
#     371             # TODO abstraction
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4030                 offsets=offsets,
#    4031                 transOffset=kwargs.pop('transform', self.transData),
# -> 4032                 alpha=alpha
#    4033                 )
#    4034         collection.set_transform(mtransforms.IdentityTransform())
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, paths, sizes, **kwargs)
#     878         Collection.__init__(self, **kwargs)
#     879         self.set_paths(paths)
# --> 880         self.set_sizes(sizes)
#     881         self.stale = True
#     882
#
# /Users/birdy/miniconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in set_sizes(self, sizes, dpi)
#     851             self._sizes = np.asarray(sizes)
#     852             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 853             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     854             self._transforms[:, 0, 0] = scale
#     855             self._transforms[:, 1, 1] = scale
#
# TypeError: ufunc 'sqrt' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
sns.set(style="ticks")

# Plot the orbital period with horizontal boxes
#sns.boxplot(x="htgr_capital_cost", y="g_lcoe", data=dat,
           #whis=np.inf, palette="vlag")

# Add in points to show each observation
sns.swarmplot(x="sfr_capital_cost", y="u_lcoe", data=dat,
              size=2, color=".3", linewidth=0)

# %%
from numpy.random import rand


fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 750
    x, y = rand(2, n)
    scale = 200.0 * rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()
